# %% [markdown]
# <div style="background-color: #e0f7e0; padding: 15px; border-radius: 5px;">
#     <h1 style="color: Darkgreen;">Home Work - Sport Athletes<br><br>
#
#         28.11.2024
# </div>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# <div style="background-color: #e0f7e0; padding: 15px; border-radius: 5px;">
#     <h3 style="color: Darkgreen;">"Read the following CSV file into a DataFrame."
# </h3>
# </div>

# %%
file_path = r'C:\users\HP\sport_athletes.csv'
df = pd.read_csv(file_path);
print(df);
# Out:
#         Country       Sport Type          Athlete Name  Height(cm)  \
# 0           USA       Basketball        Michael Jordan         198
# 1           USA       Basketball          LeBron James         206
# 2           USA       Basketball           Kobe Bryant         198
# 3           USA       Basketball          Kevin Durant         208
# 4           USA       Basketball      Shaquille O'Neal         216
# 5        Brazil           Soccer                  Pelé         174
# 6        Brazil           Soccer                 Marta         163
# 7      Portugal           Soccer     Cristiano Ronaldo         187
# 8     Argentina           Soccer          Lionel Messi         170
# 9        France           Soccer       Zinedine Zidane         185
# 10          USA           Soccer         Megan Rapinoe         168
# 11          USA         Swimming        Michael Phelps         193
# 12          USA         Swimming         Katie Ledecky         180
# ...

# %% [markdown]
# <div style="border: 2px solid Darkred; padding: 15px; background-color: #f9f9f9;">
#     <h4 style="color: Darkgreen;">
#         <strong>
#             1. For each sport type, display the highest weight, maximum height, and maximum number of wins:
#         </strong>
#         <br><br> <!-- This adds an empty line between the two parts -->
#         * a. Rename the column weight to weight_max:<br>
# * b. Rename the column height to height_max<br>
# * c. Rename the column wins to wins_max
# </div>

# %%
# Group by 'Sport Type' and get the maximum values for 'Weight', 'Height', and 'Wins'
df_max = df.groupby('Sport Type').agg(
    weight_max=('Weight(kg)', 'max'),
    height_max=('Height(cm)', 'max'),
    wins_max=('Wins', 'max')
).reset_index();

# Display the result
print(df_max);
# Out:
#         Sport Type  weight_max  height_max  wins_max
# 0       Basketball         147         216         3
# 1          Cycling          72         186         5
# 2       Gymnastics          52         160         5
# 3           Soccer          83         187         3
# 4         Swimming          90         200         5
# 5           Tennis          85         188         4
# 6  Track and Field          94         195         6

# %% [markdown]
# <div style="border: 2px solid Darkred; padding: 15px; background-color: #f9f9f9;">
#     <h4 style="color: Darkgreen;">
#         <strong>
#             2. For each sport type, display the minimum weight. Then, sort the sports by the lowest weight in ascending order:
#         </strong>
#         <br><br> <!-- This adds an empty line between the two parts -->
#         To achieve this, we need to:<br>
# a. Group the data by Sport Type and calculate the minimum weight for each sport.<br>
# b. Sort the sports based on the minimum weight in ascending order.
#
# </div>

# %%
# a. Group by 'Sport Type' and get the minimum weight for each sport:
df_min_weight = df.groupby('Sport Type').agg(
    weight_min=('Weight(kg)', 'min')
).reset_index();

# b. Sort by the minimum weight in ascending order:
df_min_weight_sorted = df_min_weight.sort_values(by='weight_min', ascending=True);

print(df_min_weight_sorted);
# Out:
#         Sport Type  weight_min
# 2       Gymnastics          45
# 3           Soccer          57
# 6  Track and Field          57
# 4         Swimming          58
# 1          Cycling          68
# 5           Tennis          70
# 0       Basketball          96

# %% [markdown]
# <div style="border: 2px solid Darkred; padding: 15px; background-color: #f9f9f9;">
#     <h4 style="color: Darkgreen;">
#         <strong>
#             3. For each sport type, display the top 2 tallest participants:
#         </strong>
#         <br><br> <!-- This adds an empty line between the two parts -->
#         To achieve this, we need to:<br
# a. Group the data by Sport Type.<br>
# b. Sort the participants within each sport by their height in descending order.<br>
# c. Select the top 2 tallest participants for each sport.
# </div>

# %%
# Group by 'Sport Type' and get the top 2 tallest participants for each sport
df_top_2_tallest = df.sort_values('Height(cm)', ascending=False) \
    .groupby('Sport Type').head(2).reset_index(drop=True);

print(df_top_2_tallest);
# Out:
#         Country       Sport Type       Athlete Name  Height(cm)  Weight(kg)  \
# 0           USA       Basketball   Shaquille O'Neal         216         147
# 1           USA       Basketball       Kevin Durant         208         109
# 2         China         Swimming           Sun Yang         200          90
# 3     Australia         Swimming         Ian Thorpe         196          85
# 4       Jamaica  Track and Field         Usain Bolt         195          94
# 5           USA  Track and Field         Carl Lewis         188          81
# 6        Serbia           Tennis     Novak Djokovic         188          84
# 7      Portugal           Soccer  Cristiano Ronaldo         187          83
# 8      Slovenia          Cycling      Primoz Roglic         186          68
# 9   Switzerland           Tennis      Roger Federer         185          85
# 10       France           Soccer    Zinedine Zidane         185          80
# ...

# %% [markdown]
# <div style="border: 2px solid Darkred; padding: 15px; background-color: #f9f9f9;">
#     <h4 style="color: Darkgreen;">
#         <strong>
#             4. Create groups based on Country and Sport Type:
#         </strong>
#         <br><br> <!-- This adds an empty line between the two parts -->
#         To achieve this, we need to:
#         <h5 style="color: black;">
# a. Display the highest statistics.<br>
# b. Display the highest statistics only for basketball in the USA. Hint: loc<br>
# c. Display the highest statistics only for football. Hint: xs<br>
# d. Display the highest statistics only for tennis and football. Hint: isin<br>
# e. Swap the indexes to Sport Type and Country, and sort the data by Sport Type + Country. Hint: swaplevel<br>
# f. Display the statistics for the values: minimum, maximum, mean, and standard deviation for the columns: Wins and Height. Hint: agg
# </div>

# %%
# a. Group by 'Country' and 'Sport Type', and get the highest statistics (max)
df_grouped_max = df.groupby(['Country', 'Sport Type']).agg({
    'Weight(kg)': 'max',
    'Height(cm)': 'max',
    'Wins': 'max'
}).reset_index();

print(df_grouped_max);
# Out:
#         Country       Sport Type  Weight(kg)  Height(cm)  Wins
# 0     Argentina           Soccer          69         170     2
# 1     Australia         Swimming          85         196     4
# 2       Belgium          Cycling          72         181     5
# 3        Brazil           Soccer          72         174     3
# 4         China         Swimming          90         200     3
# 5        France           Soccer          80         185     3
# 6       Jamaica  Track and Field          94         195     6
# 7   Netherlands          Cycling          68         175     4
# 8      Portugal           Soccer          83         187     2
# 9       Romania       Gymnastics          50         155     5
# 10       Serbia           Tennis          84         188     4
# 11     Slovenia          Cycling          69         186     3
# 12        Spain           Tennis          85         185     3
# 13  Switzerland           Tennis          85         185     2
# ...

# %%
# b. Filter data for Basketball in the USA
df_basketball_usa = df.loc[(df['Sport Type'] == 'Basketball') & (df['Country'] == 'USA')]

# Get the highest statistics
df_basketball_usa_max = df_basketball_usa[['Weight(kg)', 'Height(cm)', 'Wins']].max();

print(df_basketball_usa_max);
# Out:
# Weight(kg)    147
# Height(cm)    216
# Wins            3
# dtype: int64

# %%
# c. Get the highest statistics for Football only using xs
df_football_max = df[df['Sport Type'] == 'Football'].max();

print(df_football_max);
# Out:
# Country         NaN
# Sport Type      NaN
# Athlete Name    NaN
# Height(cm)      NaN
# Weight(kg)      NaN
# Wins            NaN
# Olympic Date    NaN
# dtype: object

# %%
# d. Filter data for Tennis and Football using isin
df_tennis_football_max = df[df['Sport Type'].isin(['Tennis', 'Football'])].max();

print(df_tennis_football_max);
# Out:
# Country                     USA
# Sport Type               Tennis
# Athlete Name    Serena Williams
# Height(cm)                  188
# Weight(kg)                   85
# Wins                          4
# Olympic Date         28/07/2008
# dtype: object

# %%
# e. Set multi-index by 'Sport Type' and 'Country'
df_indexed = df.set_index(['Sport Type', 'Country']);

# Sort the data by the multi-index
df_sorted = df_indexed.sort_index();

print(df_sorted);
# Out:
#                                      Athlete Name  Height(cm)  Weight(kg)  \
# Sport Type      Country
# Basketball      USA                Michael Jordan         198          98
#                 USA                  LeBron James         206         113
#                 USA                   Kobe Bryant         198          96
#                 USA                  Kevin Durant         208         109
#                 USA              Shaquille O'Neal         216         147
# Cycling         Belgium               Eddy Merckx         181          72
#                 Netherlands  Anna van der Breggen         175          68
#                 Slovenia            Tadej Pogacar         184          69
#                 Slovenia            Primoz Roglic         186          68
#                 UK                   Chris Froome         180          70
#                 UK                 Geraint Thomas         183          71
# ...

# %%
# f. Group by 'Country' and 'Sport Type' and get the statistics using agg
df_stats = df.groupby(['Country', 'Sport Type']).agg({
    'Wins': ['min', 'max', 'mean', 'std'],
    'Height(cm)': ['min', 'max', 'mean', 'std']
}).reset_index();

print(df_stats);
# Out:
#         Country       Sport Type Wins                        Height(cm)       \
#                                   min max      mean      std        min  max
# 0     Argentina           Soccer    2   2  2.000000      NaN        170  170
# 1     Australia         Swimming    4   4  4.000000      NaN        196  196
# 2       Belgium          Cycling    5   5  5.000000      NaN        181  181
# 3        Brazil           Soccer    3   3  3.000000  0.00000        163  174
# 4         China         Swimming    3   3  3.000000      NaN        200  200
# 5        France           Soccer    3   3  3.000000      NaN        185  185
# 6       Jamaica  Track and Field    6   6  6.000000      NaN        195  195
# 7   Netherlands          Cycling    4   4  4.000000      NaN        175  175
# 8      Portugal           Soccer    2   2  2.000000      NaN        187  187
# 9       Romania       Gymnastics    5   5  5.000000      NaN        155  155
# ...

# %% [markdown]
# <div style="border: 2px solid Darkred; padding: 15px; background-color: #f9f9f9;">
#     <h4 style="color: Darkgreen;">
#         <strong>
#             5. Add the following rows to the table using concat:
#         </strong>
#         <br><br> <!-- This adds an empty line between the two parts -->
#         <h5 style="color: black;">
# new_rows = pd.DataFrame({<br>
#     'Country': ['Canada', 'USA'],<br>
#     'Sport Type': ['Hockey', 'Skiing'],<br>
#     'Athlete Name': ['Wayne Gretzky', 'Lindsey Vonn'],<br>
#     'Height(cm)': [183, 172],<br>
#     'Weight(kg)': [84, 68],<br>
#     'Wins': [3, 4],<br>
#     'Olympic Date': ['01/02/2002', '12/02/2010']<br>
# });
# </div>

# %%
# New rows to add
new_rows = pd.DataFrame({ 
    'Country': ['Canada', 'USA'], 
    'Sport Type': ['Hockey', 'Skiing'],
    'Athlete Name': ['Wayne Gretzky', 'Lindsey Vonn'], 
    'Height(cm)': [183, 172],
    'Weight(kg)': [84, 68], 
    'Wins': [3, 4], 
    'Olympic Date': ['01/02/2002', '12/02/2010'] 
});

# Concatenate the new rows with the existing DataFrame
df_updated = pd.concat([df, new_rows], ignore_index=True);

print(df_updated);
# Out:
#         Country       Sport Type          Athlete Name  Height(cm)  \
# 0           USA       Basketball        Michael Jordan         198
# 1           USA       Basketball          LeBron James         206
# 2           USA       Basketball           Kobe Bryant         198
# 3           USA       Basketball          Kevin Durant         208
# 4           USA       Basketball      Shaquille O'Neal         216
# 5        Brazil           Soccer                  Pelé         174
# 6        Brazil           Soccer                 Marta         163
# 7      Portugal           Soccer     Cristiano Ronaldo         187
# 8     Argentina           Soccer          Lionel Messi         170
# 9        France           Soccer       Zinedine Zidane         185
# 10          USA           Soccer         Megan Rapinoe         168
# 11          USA         Swimming        Michael Phelps         193
# 12          USA         Swimming         Katie Ledecky         180
# ...

# %% [markdown]
# <div style="border: 2px solid Darkred; padding: 15px; background-color: #f9f9f9;">
#     <h4 style="color: Darkgreen;">
#         <strong>
#             6. Convert the Olympic date to datetime. Hint: datetime_to:
#         </strong>
#         <br> <!-- This adds an empty line between the two parts -->
#         <h5 style="color: black;">
# a. Now display all the wins by year using resample.<br>
# b. Add a filter so that only the years with at least one win (greater than 0) will appear.<br>
# c. Bonus: Convert all the values of 0 to NaN, then use dropna.
# </div>

# %% [markdown]
# <div style="border: 2px solid Darkred; padding: 15px; background-color: #f9f9f9;">
#     <h4 style="color: Darkgreen;">
#         <strong>
#         <h5 style="color: black;"><br>
# *** To solve this, we will follow these steps:<br>
#
# 1. Convert the "Olympic Date" column to a datetime object using pd.to_datetime().<br>
# 2. Use resample() to group the data by year and sum the wins per year.<br>
# 3. Filter the years where the total wins are greater than 0.<br>
# 4. As a bonus, replace all 0 values with NaN and use dropna() to remove rows with NaN values.
# </div>

# %%
# Step 1: Convert the Olympic Date to datetime format
df['Olympic Date'] = pd.to_datetime(df['Olympic Date'], format='%d/%m/%Y');

# Step 2: Set the Olympic Date as the index for resampling
df.set_index('Olympic Date', inplace=True);

# Step 3: Resample the data by year and sum the 'Wins' for each year
yearly_wins = df.resample('Y')['Wins'].sum();

# Step 4: Filter the years with at least one win (greater than 0)
yearly_wins_filtered = yearly_wins[yearly_wins > 0]

# Bonus: Replace all zeros in the wins column with NaN and drop rows with NaN values
df['Wins'] = df['Wins'].replace(0, pd.NA);  # Replace 0 with NaN
df_cleaned = df.dropna(subset=['Wins']);  # Drop rows where 'Wins' is NaN

# Display the results
print("Yearly wins (filtered by years with at least one win):");
print(yearly_wins_filtered);

print("\nCleaned DataFrame with 0s replaced by NaN and dropped:");
print(df_cleaned);
# Out:
# Yearly wins (filtered by years with at least one win):
# Olympic Date
# 1970-12-31     3
# 1976-12-31     5
# 1980-12-31     5
# 1984-12-31     4
# 1988-12-31     4
# 1992-12-31     3
# 1998-12-31     3
# 2000-12-31     5
# 2004-12-31     8
# 2008-12-31    13
# 2012-12-31    26
# 2016-12-31    30
# 2020-12-31    13
# Name: Wins, dtype: int64
#
# Cleaned DataFrame with 0s replaced by NaN and dropped:
#                   Country       Sport Type          Athlete Name  Height(cm)  \
# Olympic Date
# 1992-08-08            USA       Basketball        Michael Jordan         198
# 2008-08-15            USA       Basketball          LeBron James         206
# 2012-08-24            USA       Basketball           Kobe Bryant         198
# 2016-08-10            USA       Basketball          Kevin Durant         208
# 2000-08-22            USA       Basketball      Shaquille O'Neal         216
# 1970-08-18         Brazil           Soccer                  Pelé         174
# ...

# %% [markdown]
# <div style="border: 2px solid Darkred; padding: 15px; background-color: #f9f9f9;">
#     <h4 style="color: Darkgreen;">
#         <strong>
#             7. You received a CSV file documenting whether each athlete smokes or not, at the following link:
# </div>

# %%
file_path = r'C:\users\HP\athletes_smoking.csv'
df = pd.read_csv(file_path);
print(df);
# Out:
#          Athlete Name Smoking
# 0      Michael Jordan      No
# 1        LeBron James      No
# 2         Kobe Bryant     Yes
# 3          Usain Bolt      No
# 4        Simone Biles      No
# 5       Wayne Gretzky     Yes
# 6        Lindsey Vonn      No
# 7        Rafael Nadal      No
# 8        Lionel Messi     Yes
# 9   Cristiano Ronaldo      No
# 10      Megan Rapinoe      No
# 11       Kevin Durant      No
# 12   Shaquille O'Neal      No
# 13         Carl Lewis     Yes
# 14         Ian Thorpe      No

# %% [markdown]
# <div style="border: 2px solid Darkred; padding: 15px; background-color: #f9f9f9;">
#     <h4 style="color: Darkgreen;">
#         <strong>
#             7. Tasks:
#         </strong>
#         <br> <!-- This adds an empty line between the two parts -->
#         <h5 style="color: black;">
# First task:<br>
# Merge the tables so that only sports for which there is documentation about whether athletes smoke or not appear.
# <br><br>
# Second task:<br>
# Merge the tables so that all athletes appear along with the documentation about whether they smoke or not. Where there is no documentation, it should display as NaN.<br>
# </div>

# %% [markdown]
# <div style="border: 2px solid Darkred; padding: 15px; background-color: #f9f9f9;">
#     <h4 style="color: Darkgreen;">
#         <strong>
#             To merge the two tables and meet the requirements, we can follow these steps:
#         </strong>
#         <br> <!-- This adds an empty line between the two parts -->
#         <h5 style="color: black;">
# Merge the tables for sports with smoking documentation: We will merge the tables (e.g., df and df2), but only include rows where the "Smoker" column exists (i.e., those who have smoking data).
# <br><br>
# Merge the tables for all athletes: In this case, we will merge the two tables without filtering out any rows. If an athlete does not have smoking information, it will be marked as NaN.
# </div>

# %%
# Perform an inner join on 'Athlete Name' to get only the athletes with smoking data
merged_inner = pd.merge(df, athletes_smoking, on='Athlete Name', how='inner');

print(merged_inner);
# Out:
#       Country       Sport Type       Athlete Name  Height(cm)  Weight(kg)  \
# 0         USA       Basketball     Michael Jordan         198          98
# 1         USA       Basketball       LeBron James         206         113
# 2         USA       Basketball        Kobe Bryant         198          96
# 3         USA       Basketball       Kevin Durant         208         109
# 4         USA       Basketball   Shaquille O'Neal         216         147
# 5    Portugal           Soccer  Cristiano Ronaldo         187          83
# 6   Argentina           Soccer       Lionel Messi         170          69
# 7         USA           Soccer      Megan Rapinoe         168          62
# 8   Australia         Swimming         Ian Thorpe         196          85
# 9       Spain           Tennis       Rafael Nadal         185          85
# 10    Jamaica  Track and Field         Usain Bolt         195          94
# 11        USA  Track and Field         Carl Lewis         188          81
# ...

# %%
# Perform a left join on 'Athlete Name' to get all athletes, with NaN for missing smoking data
merged_left = pd.merge(df, athletes_smoking, on='Athlete Name', how='left');

print(merged_left);
# Out:
#         Country       Sport Type          Athlete Name  Height(cm)  \
# 0           USA       Basketball        Michael Jordan         198
# 1           USA       Basketball          LeBron James         206
# 2           USA       Basketball           Kobe Bryant         198
# 3           USA       Basketball          Kevin Durant         208
# 4           USA       Basketball      Shaquille O'Neal         216
# 5        Brazil           Soccer                  Pelé         174
# 6        Brazil           Soccer                 Marta         163
# 7      Portugal           Soccer     Cristiano Ronaldo         187
# 8     Argentina           Soccer          Lionel Messi         170
# 9        France           Soccer       Zinedine Zidane         185
# 10          USA           Soccer         Megan Rapinoe         168
# 11          USA         Swimming        Michael Phelps         193
# 12          USA         Swimming         Katie Ledecky         180
# ...
